# %%
from google.colab import drive
drive.mount('/content/drive')
# !unzip /content/drive/MyDrive/archive.zip -d /content/dataset
# Out:
# Mounted at /content/drive
# Archive:  /content/drive/MyDrive/archive.zip
#   inflating: /content/dataset/README.txt
#   inflating: /content/dataset/test/1030_jpg.rf.4bfc0ebc72d835cb9668219cd911c249.jpg
#   inflating: /content/dataset/test/1035_jpg.rf.0dead1ccbe6b1e137ca2d98fc4d34b9a.jpg
#   inflating: /content/dataset/test/1056_jpg.rf.f539615badbea313d68c957e76642dda.jpg
#   inflating: /content/dataset/test/1058_jpg.rf.f6d6dcde9564c091b30eb6873641ba36.jpg
#   inflating: /content/dataset/test/1083_jpg.rf.b1473a76f8f3789c6be693dfbe9bc011.jpg
#   inflating: /content/dataset/test/1093_jpg.rf.4cde54a1271fe5ecc1f9d6ca4b00f835.jpg
#   inflating: /content/dataset/test/1125_jpg.rf.6a2f54deeac86ff2d961132a828c9ae6.jpg
#   inflating: /content/dataset/test/1126_jpg.rf.d216bd33f5b8f7f557d14928c232a377.jpg
#   inflating: /content/dataset/test/1130_jpg.rf.d1672624856f1df581acc128aea4a635.jpg
#   inflating: /content/dataset/test/1136_jpg.rf.02df64849485272e48139498c36c8e44.jpg
# ...

# %%
# !git clone https://github.com/coder-ashu/ARSVD_comparison.git
# %cd ARSVD_comparison
# Out:
# Cloning into 'ARSVD_comparison'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 28 (delta 5), reused 28 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 22.56 KiB | 5.64 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /content/ARSVD_comparison

# %%
# minimal (no finetune, randomized SVD)
# !python /content/ARSVD_comparison/run_pipeline.py \
  --data_root /content/ARSVD_comparison/data \
  --out_dir ./artifacts_run \
  --device cuda \
  --epochs 10 \
  --svd_ranks "32,16" \
  --arsvd_taus "0.9,0.85"
# Out:
# INFO:pipelines.train_pipeline:Starting pipeline 'arsvd_training_pipeline' with 3 steps.
# INFO:pipelines.train_pipeline:Executing step `ingest_step`; expects_input=False
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# INFO:pipelines.train_pipeline:Step[0] 'ingest_step' completed. Output type: <class 'tuple'>
# ...

# %%
# !pip install optuna
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 11.7 MB/s eta 0:00:00
# ...
